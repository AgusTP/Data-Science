# %% [markdown]
# <a href="https://colab.research.google.com/github/AgusTP/Data-Science/blob/master/Spotify_top_50_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Spotify 50 songs

# %% [markdown]
# Let's do some EDA and visualizations about the dataset:
# - It contains the top 50 most listened songs in the world by spotify, their Genre, Beats per minute, and more.

# %% [markdown]
# **Importing modules and packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.express as px
from PIL import Image
from wordcloud import WordCloud

from google.colab import drive 
drive.mount('/content/gdrive')

# %matplotlib inline
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# **Getting to know the data**

# %%
dataset = pd.read_csv('gdrive/My Drive/top50.csv', encoding = "ISO-8859-1")
dataset.head()
# Out:
#    Unnamed: 0                       Track.Name  ... Speechiness. Popularity
# 0           1                         Señorita  ...            3         79
# 1           2                            China  ...            9         92
# 2           3    boyfriend (with Social House)  ...           46         85
# 3           4  Beautiful People (feat. Khalid)  ...           19         86
# 4           5      Goodbyes (Feat. Young Thug)  ...            7         94
#
# [5 rows x 14 columns]

# %% [markdown]
# **The set contains has:**
# - 3 categorical columns: 'Track Name', 'Artist Name' and 'Genre'.
# - 10 numerical columns: 'BPM', 'Energy', 'Danceability', 'Loudness (dB)', 'Liveness (live record)', 'Valence (Mood)', 'Lenght', 'Acousticness', 'Popularity'.

# %%
dataset = dataset.drop(['Unnamed: 0'], axis = 1)

# %%
dataset.columns = ['Track_Name', 'Artist_Name', 'Genre', 'BPM', 'Energy', 'Danceability', 'dB', 'Liveness','Valence',
                  'Length(s)', 'Acousticness','Speechiness','Popularity']

# %% [markdown]
# ## EDA and visualizations

# %% [markdown]
# **Distribution of features**

# %%
hist_data = [dataset['Danceability'], dataset['Popularity'], dataset['Acousticness']]
group_labels = [ 'Danceability','Popularity','Acousticness']

fig = ff.create_distplot(hist_data, group_labels, bin_size=[10, 10,1], colors = ['#F66095', '#2BCDC1', '#393E46'])
fig.update_layout(title_text='Popularity, Danceability and Acousticness')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4086b40-69cf-4efe-8764-870926cf743a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4086b40-69cf-4efe-8764-870926cf743a")) {
#                     Plotly.newPlot(
#                         'a4086b40-69cf-4efe-8764-870926cf743a',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Danceability", "marker": {"color": "#F66095"}, "name": "Danceability", "opacity": 0.7, "type": "histogram", "x": [76, 79, 40, 64, 58, 80, 75, 48, 88, 70, 61, 82, 50, 73, 83, 70, 75, 76, 84, 72, 68, 70, 81, 80, 67, 69, 82, 73, 74, 64, 29, 78, 78, 80, 77, 66, 75, 72, 84, 81, 69, 77, 57, 90, 88, 66, 67, 69, 59, 75], "xaxis": "x", "xbins": {"end": 90.0, "size": 10, "start": 29.0}, "yaxis": "y"}, {"autobinx": false, "histnorm": "probability density", "legendgroup": "Popularity", "marker": {"color": "#2BCDC1"}, "name": "Popularity", "opacity": 0.7, "type": "histogram", "x": [79, 92, 85, 86, 94, 84, 92, 90, 87, 95, 93, 86, 88, 87, 92, 82, 90, 91, 88, 91, 91, 91, 83, 91, 89, 70, 83, 89, 91, 89, 84, 89, 89, 89, 89, 89, 91, 87, 80, 78, 88, 90, 87, 84, 88, 88, 88, 88, 88, 82], "xaxis": "x", "xbins": {"end": 95.0, "size": 10, "start": 70.0}, "yaxis": "y"}, {"autobinx": false, "histnorm": "probability density", "legendgroup":
# %% [markdown]
# Top songs seem to be highly danceable and not acoustic!

# %% [markdown]
# **Top artists and top Genres**

# %%
Artists = pd.DataFrame(dataset['Artist_Name'].value_counts()).reset_index()
Artists.columns = ['Artist','Total songs']

# %%
fig = px.bar(Artists, x = 'Artist', y = 'Total songs', color = 'Artist', title='Artist vs amount of top songs')        
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e086f65d-7704-40a6-a157-71c009187932" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e086f65d-7704-40a6-a157-71c009187932")) {
#                     Plotly.newPlot(
#                         'e086f65d-7704-40a6-a157-71c009187932',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Ed Sheeran", "marker": {"color": "#636efa"}, "name": "Artist=Ed Sheeran", "offsetgroup": "Artist=Ed Sheeran", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ed Sheeran"], "xaxis": "x", "y": [4], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Billie Eilish", "marker": {"color": "#EF553B"}, "name": "Artist=Billie Eilish", "offsetgroup": "Artist=Billie Eilish", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Billie Eilish"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=The Chainsmokers", "marker": {"color": "#00cc96"}, "name": "Artist=The Chainsmokers", "offsetgroup": "Artist=The Chainsmokers", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["The Chainsmokers"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Shawn Mendes", "marker": {"color": "#ab63fa"}, "name": "Artist=Shawn Mendes", "offsetgroup": "Artist=Shawn Mendes", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Shawn Mendes"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Ariana Grande", "marker": {"color": "#FFA15A"}, "name": "Artist=Ariana Grande", "offsetgroup": "Artist=Ariana Grande", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ariana Grande"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Post Malone", "marker": {"color": "#19d3f3"}, "name": "Artist=Post Malone", "offsetgroup": "Artist=Post Malone", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Post Malone"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Marshmello", "marker": {"color": "#FF6692"}, "name": "Artist=Marshmello", "offsetgroup": "Artist=Marshmello", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Marshmello"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Lil Nas X", "marker": {"color": "#B6E880"}, "name": "Artist=Lil Nas X", "offsetgroup": "Artist=Lil Nas X", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Lil Nas X"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=Sech", "marker": {"color": "#FF97FF"}, "name": "Artist=Sech", "offsetgroup": "Artist=Sech", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sech"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", "legendgroup": "Artist=J Balvin", "marker": {"color": "#FECB52"}, "name": "Artist=J Balvin", "offsetgroup": "Artist=J Balvin", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["J Balvin"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Artist=%{x}<br>Total songs=%{y}", ...

# %%
Genre = pd.DataFrame(dataset['Genre'].value_counts()).reset_index()
Genre.columns = ['Genre','Total songs']
fig = px.bar(Genre, x = 'Genre', y = 'Total songs', color = 'Genre', title='Genre vs amount of top songs')        
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f77fee6-82cc-4f4e-bd8c-3d85779f9477" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f77fee6-82cc-4f4e-bd8c-3d85779f9477")) {
#                     Plotly.newPlot(
#                         '4f77fee6-82cc-4f4e-bd8c-3d85779f9477',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=dance pop", "marker": {"color": "#636efa"}, "name": "Genre=dance pop", "offsetgroup": "Genre=dance pop", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["dance pop"], "xaxis": "x", "y": [8], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=pop", "marker": {"color": "#EF553B"}, "name": "Genre=pop", "offsetgroup": "Genre=pop", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["pop"], "xaxis": "x", "y": [7], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=latin", "marker": {"color": "#00cc96"}, "name": "Genre=latin", "offsetgroup": "Genre=latin", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["latin"], "xaxis": "x", "y": [5], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=canadian hip hop", "marker": {"color": "#ab63fa"}, "name": "Genre=canadian hip hop", "offsetgroup": "Genre=canadian hip hop", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["canadian hip hop"], "xaxis": "x", "y": [3], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=edm", "marker": {"color": "#FFA15A"}, "name": "Genre=edm", "offsetgroup": "Genre=edm", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["edm"], "xaxis": "x", "y": [3], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=reggaeton flow", "marker": {"color": "#19d3f3"}, "name": "Genre=reggaeton flow", "offsetgroup": "Genre=reggaeton flow", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["reggaeton flow"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=brostep", "marker": {"color": "#FF6692"}, "name": "Genre=brostep", "offsetgroup": "Genre=brostep", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["brostep"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=dfw rap", "marker": {"color": "#B6E880"}, "name": "Genre=dfw rap", "offsetgroup": "Genre=dfw rap", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["dfw rap"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=country rap", "marker": {"color": "#FF97FF"}, "name": "Genre=country rap", "offsetgroup": "Genre=country rap", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["country rap"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=reggaeton", "marker": {"color": "#FECB52"}, "name": "Genre=reggaeton", "offsetgroup": "Genre=reggaeton", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["reggaeton"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=%{x}<br>Total songs=%{y}", "legendgroup": "Genre=panamanian pop", "marker": {"color": "#636efa"}, "name": "Genre=panamanian pop", "offsetgroup": "Genre=pan ...

# %% [markdown]
# - There are a few top artists with 2 or more songs in the top 50.
# - There are mainly three top genres: Dance Pop, Pop and Latin.

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x = "Popularity", y = "Genre", data=dataset, palette = 'Set1')

plt.xlabel('Popularity', fontsize=16)
plt.ylabel('Genre', fontsize=16)
plt.yticks(rotation='0')
plt.title("Genre vs popularity", fontsize=20)
plt.show()

# %% [markdown]
# ## Let's analyze the correlation between the top 50 songs

# %%
x = dataset.columns[3:]
heat = go.Heatmap(z =dataset.corr(),
                  x = x,
                  y = x,
                  xgap=1, ygap=1,
                  colorbar_thickness=20,
                  colorbar_ticklen=3,
                  hovertext = dataset.corr(),
                  hoverinfo='text',colorscale=[[0.0, '#F5FFFA'], 
                         [0.2, '#ADD8E6'], 
                         [0.4, '#87CEEB'],
                         [0.6, '#87CEFA'], 
                         [0.8, '#40E0D0'], 
                         [1.0, '#00CED1']]
                   )

title = 'Correlation Matrix'               

layout = go.Layout(title_text=title, title_x=0.5, 
                   width=600, height=600,
                   xaxis_showgrid=False,
                   yaxis_showgrid=False,
                   yaxis_autorange='reversed')
   
fig=go.Figure(data=[heat], layout=layout)        
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="30ba9a6a-1ac1-49fe-baa3-20d9821934ad" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("30ba9a6a-1ac1-49fe-baa3-20d9821934ad")) {
#                     Plotly.newPlot(
#                         '30ba9a6a-1ac1-49fe-baa3-20d9821934ad',
#                         [{"colorbar": {"thickness": 20, "ticklen": 3}, "colorscale": [[0.0, "#F5FFFA"], [0.2, "#ADD8E6"], [0.4, "#87CEEB"], [0.6, "#87CEFA"], [0.8, "#40E0D0"], [1.0, "#00CED1"]], "hoverinfo": "text", "hovertext": [[1.0, 0.04375559078974287, -0.09418289163246002, 0.01701618522178128, -0.16728576129833583, -0.011585815624504931, -0.13928839968965537, -0.031449596645926205, 0.5570518776006887, 0.19609691805289695], [0.04375559078974287, 1.0, 0.01825357584565256, 0.6707935666326849, 0.16276770654829992, 0.43881958610521743, 0.22467680636792148, -0.33989165317345377, -0.08985966770834465, -0.08029496868638145], [-0.09418289163246002, 0.01825357584565256, 1.0, 0.01625453699804858, -0.14963620230315283, 0.1728289767815293, -0.00018529761721181146, -0.09816537737235881, -0.1034719216937956, -0.0714132525873347], [0.01701618522178128, 0.6707935666326849, 0.01625453699804858, 1.0, 0.258652034949047, 0.23761380024226456, 0.21921874069163522, -0.13829960706824224, -0.27221263338218205, -0.04308543081522875], [-0.16728576129833583, 0.16276770654829992, -0.14963620230315283, 0.258652034949047, 1.0, 0.01612346671918521, 0.13178233539855644, 0.021328241046500204, -0.12528606235105302, 0.09256423062072731], [-0.011585815624504931, 0.43881958610521743, 0.1728289767815293, 0.23761380024226456, 0.01612346671918521, 1.0, -0.01778177718536444, -0.052323306099632476, -0.05324174625294804, -0.3177523630641457], [-0.13928839968965537, 0.22467680636792148, -0.00018529761721181146, 0.21921874069163522, 0.13178233539855644, -0.01778177718536444, 1.0, -0.07629269009145838, 0.04675526087355612, -0.08763885890077106], [-0.031449596645926205, -0.33989165317345377, -0.09816537737235881, -0.13829960706824224, 0.021328241046500204, -0.052323306099632476, -0.07629269009145838, 1.0, 0.008293376454957748, -0.03468404109745295], [0.5570518776006887, -0.08985966770834465, -0.1034719216937956, -0.27221263338218205, -0.12528606235105302, -0.05324174625294804, 0.04675526087355612, 0.008293376454957748, 1.0, 0.23855303243722875], [0.19609691805289695, -0.08029496868638145, -0.0714132525873347, -0.04308543081522875, 0.09256423062072731, -0.3177523630641457, -0.08763885890077106, -0.03468404109745295, 0.23855303243722875, 1.0]], "type": "heatmap", "x": ["BPM", "Energy", "Danceability", "dB", "Liveness", "Valence", "Length(s)", "Acousticness", "Speechiness", "Popularity"], "xgap": 1, "y": ["BPM", "Energy", "Danceability", "dB", "Liveness", "Valence", "Length(s)", "Acousticness", "Speechiness", "Popularity"], "ygap": 1, "z": [[1.0, 0.04375559078974287, -0.09418289163246002, 0.01701618522178128, -0.16728576129833583, -0.011585815624504931, -0.13928839968965537, -0.031449596645926205, 0.5570518776006887, 0.19609691805289695], [0.04375559078974287, 1.0, 0.01825357584565256, 0.6707935666326849, 0.16276770654829992, 0.43881958610521743, 0.22467680636792148, -0.33989165317345377, -0.08985966770834465, -0.08029496868638145], [-0.09418289163246002, 0.01825357584565256, 1.0, 0.01625453699804858, -0.14963620230315283, 0.1728289767815293, -0.00018529761721181146, -0.09816537737235881, -0.1034719216937956, -0.0714132525873347], [0.01701618522178128, 0.6707935666326849, 0.01625453699804858, 1.0, 0.258652034949047, 0.23761380024226456, 0.21921874069163522, -0.13829960706824224, -0.27221263338218205, -0.04308543081522875], [-0.16728576129833583, 0.16276770654829992, -0.14963620230315283, 0.258652034949047, 1.0, 0.01612346671918521, 0.13178233539855644, 0.021328241046500204, -0.12528606235105302, 0.09256423062072731], [-0.011585815624504931, 0.43881958610521743, 0.1728289767815293, 0.23761380024226456, 0.01612346671918521, 1.0, -0.01778177718536444, -0.052323306099632476, -0.05324174625294804, -0.3177523630641457], [-0.13928839968965537, 0.22467680636792148, -0.00018529761721181146, 0.21921874069163522, 0.13178233539855644, -0.01778177718536444, 1.0, -0.07629269009145838, 0.04675526087355612, -0.08763885890077106], [-0.031449596645926205, -0.33989165317345377, -0.0981653773 ...
#                         {"height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"o

# %% [markdown]
# So we can see that there are no clear correlations with 'Popularity'. There is no recipe for a song to be among the top 50!
#
# Correlations seen:
# - Speechiness and BPM
# - Energy and dB

# %%
fig = px.scatter(dataset, x = "Speechiness", y = "BPM", size='Popularity', color = "Genre", title = 'BPM vs. Speechiness')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7ed93268-8eaa-43aa-a191-df91f8723652" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ed93268-8eaa-43aa-a191-df91f8723652")) {
#                     Plotly.newPlot(
#                         '7ed93268-8eaa-43aa-a191-df91f8723652',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=canadian pop<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=canadian pop", "marker": {"color": "#636efa", "size": [79, 70], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=canadian pop", "showlegend": true, "type": "scatter", "x": [3, 6], "xaxis": "x", "y": [117, 124], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=reggaeton flow<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=reggaeton flow", "marker": {"color": "#EF553B", "size": [92, 83], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=reggaeton flow", "showlegend": true, "type": "scatter", "x": [9, 7], "xaxis": "x", "y": [105, 92], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=dance pop<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=dance pop", "marker": {"color": "#00cc96", "size": [85, 86, 82, 89, 89, 78, 90, 87], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=dance pop", "showlegend": true, "type": "scatter", "x": [46, 7, 15, 33, 6, 7, 5, 3], "xaxis": "x", "y": [190, 96, 93, 140, 100, 95, 85, 96], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=pop<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=pop", "marker": {"color": "#ab63fa", "size": [86, 84, 90, 88, 87, 84, 82], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=pop", "showlegend": true, "type": "scatter", "x": [19, 4, 9, 3, 5, 13, 12], "xaxis": "x", "y": [93, 102, 111, 110, 152, 136, 95], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=dfw rap<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=dfw rap", "marker": {"color": "#FFA15A", "size": [94, 91], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=dfw rap", "showlegend": true, "type": "scatter", "x": [7, 5], "xaxis": "x", "y": [150, 90], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=trap music<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=trap music", "marker": {"color": "#19d3f3", "size": [92], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=trap music", "showlegend": true, "type": "scatter", "x": [29], "xaxis": "x", "y": [180], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=country rap<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=country rap", "marker": {"color": "#FF6692", "size": [87, 91], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=country rap", "showlegend": true, "type": "scatter", "x": [10, 8], "xaxis": "x", "y": [136, 154], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=electropop<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=electropop", "marker": {"color": "#B6E880", "size": [95, 89], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=electropop", "showlegend": true, "type": "scatter", "x": [38, 30], "xaxis": "x", "y": [135, 135], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=reggaeton<br>Speechiness=%{x}<br>BPM=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=reggaeton", "marker": {"color": "#FF97FF", "size": [93, 89], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=reggaeton", "showlegend": true, "type": "scatter", "x": [31, 28], "xaxis": "x", "y": [176, 96], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=panamanian pop<br>Spe ...

# %%
fig = px.scatter(dataset, x = "Energy", y = "dB", size='Popularity', color = "Genre", title = 'Energy vs. dB')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6d788f3e-8a0d-4ebb-b2a7-15d9246db3bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d788f3e-8a0d-4ebb-b2a7-15d9246db3bf")) {
#                     Plotly.newPlot(
#                         '6d788f3e-8a0d-4ebb-b2a7-15d9246db3bf',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=canadian pop<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=canadian pop", "marker": {"color": "#636efa", "size": [79, 70], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=canadian pop", "showlegend": true, "type": "scatter", "x": [55, 82], "xaxis": "x", "y": [-6, -4], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=reggaeton flow<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=reggaeton flow", "marker": {"color": "#EF553B", "size": [92, 83], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=reggaeton flow", "showlegend": true, "type": "scatter", "x": [81, 79], "xaxis": "x", "y": [-4, -4], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=dance pop<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=dance pop", "marker": {"color": "#00cc96", "size": [85, 86, 82, 89, 89, 78, 90, 87], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=dance pop", "showlegend": true, "type": "scatter", "x": [80, 71, 45, 32, 88, 56, 68, 39], "xaxis": "x", "y": [-4, -4, -7, -11, -5, -6, -6, -6], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=pop<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=pop", "marker": {"color": "#ab63fa", "size": [86, 84, 90, 88, 87, 84, 82], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=pop", "showlegend": true, "type": "scatter", "x": [65, 68, 68, 41, 82, 40, 79], "xaxis": "x", "y": [-8, -5, -5, -6, -5, -9, -6], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=dfw rap<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=dfw rap", "marker": {"color": "#FFA15A", "size": [94, 91], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=dfw rap", "showlegend": true, "type": "scatter", "x": [65, 48], "xaxis": "x", "y": [-4, -6], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=trap music<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=trap music", "marker": {"color": "#19d3f3", "size": [92], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=trap music", "showlegend": true, "type": "scatter", "x": [64], "xaxis": "x", "y": [-6], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=country rap<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=country rap", "marker": {"color": "#FF6692", "size": [87, 91], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=country rap", "showlegend": true, "type": "scatter", "x": [62, 59], "xaxis": "x", "y": [-6, -6], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=electropop<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=electropop", "marker": {"color": "#B6E880", "size": [95, 89], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=electropop", "showlegend": true, "type": "scatter", "x": [43, 45], "xaxis": "x", "y": [-11, -11], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=reggaeton<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "legendgroup": "Genre=reggaeton", "marker": {"color": "#FF97FF", "size": [93, 89], "sizemode": "area", "sizeref": 0.2375, "symbol": "circle"}, "mode": "markers", "name": "Genre=reggaeton", "showlegend": true, "type": "scatter", "x": [62, 71], "xaxis": "x", "y": [-5, -5], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Genre=panamanian pop<br>Energy=%{x}<br>dB=%{y}<br>Popularity=%{marker.size}", "l ...

# %% [markdown]
# ## Energy vs. Danceability

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x = dataset["Energy"], y = dataset['Danceability'], height=10 ,kind="kde", color='purple')

plt.ylabel('Danceability', fontsize=12)
plt.xlabel("Energy", fontsize=12)
plt.title("Energy Vs Danceability", fontsize=15)

plt.show()

# %%
hist_data = [dataset['Energy'], dataset['Danceability']]
group_labels = [ 'Energy','Danceability']

fig = ff.create_distplot(hist_data, group_labels, bin_size=[10, 10], colors = ['#D4323E', '#3466D4'])
fig.update_layout(title_text='Energy vs Danceability')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1a929515-635b-4998-a374-043ec50fcde0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1a929515-635b-4998-a374-043ec50fcde0")) {
#                     Plotly.newPlot(
#                         '1a929515-635b-4998-a374-043ec50fcde0',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Energy", "marker": {"color": "#D4323E"}, "name": "Energy", "opacity": 0.7, "type": "histogram", "x": [55, 81, 80, 65, 65, 68, 64, 68, 62, 43, 62, 71, 41, 79, 50, 45, 65, 48, 39, 62, 74, 59, 79, 78, 45, 82, 59, 46, 86, 79, 51, 32, 71, 59, 88, 72, 70, 82, 73, 56, 68, 68, 39, 40, 69, 62, 75, 79, 70, 79], "xaxis": "x", "xbins": {"end": 88.0, "size": 10, "start": 32.0}, "yaxis": "y"}, {"autobinx": false, "histnorm": "probability density", "legendgroup": "Danceability", "marker": {"color": "#3466D4"}, "name": "Danceability", "opacity": 0.7, "type": "histogram", "x": [76, 79, 40, 64, 58, 80, 75, 48, 88, 70, 61, 82, 50, 73, 83, 70, 75, 76, 84, 72, 68, 70, 81, 80, 67, 69, 82, 73, 74, 64, 29, 78, 78, 80, 77, 66, 75, 72, 84, 81, 69, 77, 57, 90, 88, 66, 67, 69, 59, 75], "xaxis": "x", "xbins": {"end": 90.0, "size": 10, "start": 29.0}, "yaxis": "y"}, {"legendgroup": "Energy", "marker": {"color": "#D4323E"}, "mode": "lines", "name": "Energy", "showlegend": false, "type": "scatter", "x": [32.0, 32.112, 32.224, 32.336, 32.448, 32
# %% [markdown]
# ## Speechines vs. dB

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x = dataset["Speechiness"], y = dataset['BPM'], height=10 ,kind="kde", color='turquoise')

plt.ylabel('BPM', fontsize=12)
plt.xlabel("Speechiness", fontsize=12)
plt.title("Speechiness Vs BPM", fontsize=15)

plt.show()

# %%
hist_data = [dataset['Speechiness'], dataset['BPM']]
group_labels = [ 'Speechiness','BPM']

fig = ff.create_distplot(hist_data, group_labels, bin_size=[12, 12], colors = ['#2462ab', '#2ba323'])
fig.update_layout(title_text='Speechiness vs BPM')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="41e76f72-c617-420e-973c-20b276985b45" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41e76f72-c617-420e-973c-20b276985b45")) {
#                     Plotly.newPlot(
#                         '41e76f72-c617-420e-973c-20b276985b45',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Speechiness", "marker": {"color": "#2462ab"}, "name": "Speechiness", "opacity": 0.7, "type": "histogram", "x": [3, 9, 46, 19, 7, 4, 29, 9, 10, 38, 31, 7, 3, 20, 5, 15, 32, 5, 8, 11, 3, 8, 7, 4, 30, 6, 10, 3, 6, 25, 4, 33, 28, 15, 6, 6, 34, 5, 6, 7, 3, 5, 3, 13, 12, 5, 6, 5, 3, 12], "xaxis": "x", "xbins": {"end": 46.0, "size": 12, "start": 3.0}, "yaxis": "y"}, {"autobinx": false, "histnorm": "probability density", "legendgroup": "BPM", "marker": {"color": "#2ba323"}, "name": "BPM", "opacity": 0.7, "type": "histogram", "x": [117, 105, 190, 93, 150, 102, 180, 111, 136, 135, 176, 96, 110, 176, 101, 93, 176, 90, 130, 158, 124, 154, 92, 92, 135, 124, 98, 96, 94, 93, 85, 140, 96, 98, 100, 114, 176, 152, 138, 95, 104, 85, 96, 136, 98, 88, 176, 100, 104, 95], "xaxis": "x", "xbins": {"end": 190.0, "size": 12, "start": 85.0}, "yaxis": "y"}, {"legendgroup": "Speechiness", "marker": {"color": "#2462ab"}, "mode": "lines", "name": "Speechiness", "showlegend": false, "type": "scatter", "x": [3.0, 3.086, 3.172, 3.258, 3.344, 3.43, 3.516, 3.602, 3.6879999999999997, 3.774, 3.86, 3.9459999999999997, 4.032, 4.118, 4.204, 4.29, 4.3759999999999994, 4.462, 4.548, 4.634, 4.72, 4.806, 4.8919999999999995, 4.978, 5.064, 5.15, 5.236000000000001, 5.322, 5.4079999999999995, 5.494, 5.58, 5.666, 5.752, 5.838, 5.9239999999999995, 6.01, 6.096, 6.182, 6.268, 6.354, 6.4399999999999995, 6.526, 6.612, 6.698, 6.784, 6.87, 6.9559999999999995, 7.042, 7.128, 7.214, 7.3, 7.386, 7.472, 7.558, 7.644, 7.73, 7.816, 7.902, 7.988, 8.074, 8.16, 8.246, 8.332, 8.418, 8.504, 8.59, 8.676, 8.762, 8.847999999999999, 8.934000000000001, 9.02, 9.106, 9.192,